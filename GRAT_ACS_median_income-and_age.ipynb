# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import ttest_rel, wilcoxon

import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
path1= "../FCI/ACS_2023_Median_Income_by_Race_and_Age_Selp_Emp_Boundaries.csv"
path2= "../FCI/ACS_10_14_Median_Income_by_Race_and_Age_Selp_Emp_Boundaries.csv"

ACS_median_income_23= pd.read_csv(path1)
ACS_median_income_14= pd.read_csv(path2)

# %%
ACS_merge = pd.merge(ACS_median_income_23,ACS_median_income_14, on='Name', how='inner', suffixes=('_2023', '_2014'))

# %%
print(ACS_merge.columns)
# Out:
# Index(['Object_ID_2023', 'Geographic_Identifier_-_FIPS_Code_2023',
#        'Area_of_Land_(Square_Meters)_2023',
#        'Area_of_Water_(Square_Meters)_2023', 'Name', 'State_2023',
#        'County_2023',
#        'Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2023',
#        'Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_under_25_years_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_under_25_years_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_25_to_44_years_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_25_to_44_years_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_45_to_64_years_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_45_to_64_years_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_65_years_and_over_2023',
#        'Median_Household_Income_in_past_12_months,_Householder_65_years_and_over_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2023',
#        'Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_American_Indian_and_Alaska_Native_Alone_Householder_2023',
#        'Median_Household_Income_in_past_12_months,_American_Indian_and_Alaska_Native_Alone_Householder_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Asian_Alone_Householder_2023',
#        'Median_Household_Income_in_past_12_months,_Asian_Alone_Householder_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Native_Hawaiian_and_Other_Pacific_Islander_Alone_Householder_2023',
#        'Median_Household_Income_in_past_12_months,_Native_Hawaiian_and_Other_Pacific_Islander_Alone_Householder_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Some_Other_Race_Alone_Householder_2023',
#        'Median_Household_Income_in_past_12_months,_Some_Other_Race_Alone_Householder_-_Margin_of_Error_2023',
#        'Median_Household_Income_in_past_12_months,_Two_or_More_Races_Householder',
#        'Median_Household_Income_in_past_12_months,_Two_or_More_Races_Householder_-_Margin_of_Error',
#        'Median_Household_Income_in_past_12_months,_White_alone,_not_Hispanic_Householder',
#        'Median_Household_Income_in_past_12_months,_White_alone,_not_Hispanic_Householder_-_Margin_of_Error',
#        'Median_Household_Income_in_past_12_months,_Hispanic_or_Latino_Householder_2023',
#        'Median_Household_Income_in_past_12_months,_Hispanic_or_Latino_Householder_-_Margin_of_Error_2023',
#        'Total_Households_2023', 'Total_Households_-_Margin_of_Error_2023',
#        'Households_with_any_self-employment_income_in_past_12_months_2023',
#        'Households_with_any_self-employment_income_in_past_12_months_-_Margin_of_Error_2023',
#        'Households_with_no_self-employment_income_in_past_12_months_2023',
#        'Households_with_no_self-employment_income_in_past_12_months_-_Margin_of_Error_2023',
#        'Percent_of_households_with_any_self-employment_income_2023',
#        'Percent_of_households_with_any_self-employment_income_-_Margin_of_Error_2023',
#        'Shape_Area_2023', 'Shape_Length_2023', 'Object_ID_2014',
#        'Geographic_Identifier_-_FIPS_Code_2014',
#        'Area_of_Land_(Square_Meters)_2014',
#        'Area_of_Water_(Square_Meters)_2014', 'State_2014', 'County_2014',
#        'Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2014',
#        'Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_under_25_years_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_under_25_years_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_25_to_44_years_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_25_to_44_years_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_45_to_64_years_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_45_to_64_years_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_65_years_and_over_2014',
#        'Median_Household_Income_in_past_12_months,_Householder_65_years_and_over_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2014',
#        'Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_American_Indian_and_Alaska_Native_Alone_Householder_2014',
#        'Median_Household_Income_in_past_12_months,_American_Indian_and_Alaska_Native_Alone_Householder_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Asian_Alone_Householder_2014',
#        'Median_Household_Income_in_past_12_months,_Asian_Alone_Householder_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Native_Hawaiian_and_Other_Pacific_Islander_Alone_Householder_2014',
#        'Median_Household_Income_in_past_12_months,_Native_Hawaiian_and_Other_Pacific_Islander_Alone_Householder_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_Some_Other_Race_Alone_Householder_2014',
#        'Median_Household_Income_in_past_12_months,_Some_Other_Race_Alone_Householder_-_Margin_of_Error_2014',
#        'Median_Household_Income_in_past_12_months,_2_or_More_Races_Householder',
#        'Median_Household_Income_in_past_12_months,_2_or_More_Races_Householder_-_Margin_of_Error',
#        'Median_Household_Income_in_past_12_months,_White_Alone,_Not_Hispanic_Householder',
#        'Median_Household_Income_in_past_12_months,_White_Alone,_Not_Hispanic_Householder_-_Margin_of_Error',
#        'Median_Household_Income_in_past_12_months,_Hispanic_or_Latino_Householder_2014',
#        'Median_Household_Income_in_past_12_months,_Hispanic_or_Latino_Householder_-_Margin_of_Error_2014',
#        'Total_Households_2014', 'Total_Households_-_Margin_of_Error_2014',
#        'Households_with_any_self-employment_income_in_past_12_months_2014',
#        'Households_with_any_self-employment_income_in_past_12_months_-_Margin_of_Error_2014',
#        'Households_with_no_self-employment_income_in_past_12_months_2014',
#        'Households_with_no_self-employment_income_in_past_12_months_-_Margin_of_Error_2014',
#        'Percent_of_households_with_any_self-employment_income_2014',
#        'Percent_of_households_with_any_self-employment_income_-_Margin_of_Error_2014',
#        'Shape_Area_2014', 'Shape_Length_2014'],
#       dtype='object')

# %%
ACS_merge['Median_Household_Income_in_past_12_months'] = ACS_merge['Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2023'] - ACS_merge['Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2014']
ACS_merge['Median_Household_Income_in_past_12_months_under_25'] = ACS_merge['Median_Household_Income_in_past_12_months,_Householder_under_25_years_2023'] - ACS_merge['Median_Household_Income_in_past_12_months,_Householder_under_25_years_2014']
ACS_merge['Median_Household_Income_in_past_12_months_African_American'] = ACS_merge['Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2023'] - ACS_merge['Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2014']
ACS_merge['Total_House_Hold'] = ACS_merge['Total_Households_2023'] - ACS_merge['Total_Households_2014']

# %%
X= ACS_merge[['Median_Household_Income_in_past_12_months','Median_Household_Income_in_past_12_months_under_25','Median_Household_Income_in_past_12_months_African_American','Total_House_Hold']]
Y= ACS_merge['Median_Household_Income_in_past_12_months,_Householder_under_25_years_2023']

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2, random_state=0)

model= LinearRegression()
model.fit(X_train,Y_train)

Y_pred = model.predict(X_test)

# %%
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

MSE= mean_squared_error(Y_test, Y_pred)
R2=r2_score(Y_test,Y_pred)
print("Mean Squared Error:", MSE)
print("R^2 score:",R2)
# Out:
# Coefficients: [ 0.23502569  0.74975492  0.01468993 -6.16304042]
# Intercept: 9375.902844538694
# Mean Squared Error: 53707180.55244131
# R^2 score: 0.8904964842185048

# %%
descriptive_stats_2014 = ACS_median_income_14.describe()
descriptive_stats_2023 = ACS_median_income_23.describe()

print("Descriptive Statistics for 2014:")
print(descriptive_stats_2014)
print("\nDescriptive Statistics for 2023:")
print(descriptive_stats_2023)
# Out:
# Descriptive Statistics for 2014:
#          Object_ID  Geographic_Identifier_-_FIPS_Code  \
# count    56.000000                       5.600000e+01
# mean   2891.500000                       1.200100e+10
# std      16.309506                       1.461311e+04
# min    2864.000000                       1.200100e+10
# 25%    2877.750000                       1.200100e+10
# 50%    2891.500000                       1.200100e+10
# 75%    2905.250000                       1.200100e+10
# max    2919.000000                       1.200111e+10
#
#        Area_of_Land_(Square_Meters)  Area_of_Water_(Square_Meters)  \
# count                  5.600000e+01                   5.600000e+01
# mean                   4.047105e+07                   4.336130e+06
# std                    7.238478e+07                   1.615153e+07
# min                    5.246420e+05                   0.000000e+00
# 25%                    2.411816e+06                   8.837750e+03
# 50%                    7.563150e+06                   4.469150e+04
# 75%                    2.676584e+07                   7.994012e+05
# max                    3.183814e+08                   8.703560e+07
#
#        Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)  \
# count                                          56.000000
# mean                                        44653.285714
# std                                         24206.061223
# min                                         15554.000000
# 25%                                         28103.500000
# 50%                                         37287.500000
# 75%                                         58197.750000
# max                                        123500.000000
#
#        Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_-_Margin_of_Error  \
# count                                          56.000000
# mean                                         9265.160714
# std                                          5106.933959
# min                                          1529.000000
# 25%                                          6189.500000
# 50%                                          8236.000000
# 75%                                         11162.000000
# max                                         26123.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_under_25_years  \
# count                                          56.000000
# mean                                        13070.910714
# std                                         15565.223593
# min                                             0.000000
# 25%                                             0.000000
# 50%                                          8521.000000
# 75%                                         19598.250000
# max                                         68051.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_under_25_years_-_Margin_of_Error  \
# count                                          56.000000
# mean                                         7917.464286
# std                                          9268.553148
# min                                             0.000000
# 25%                                             0.000000
# 50%                                          4606.000000
# 75%                                         12153.000000
# max                                         38549.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_25_to_44_years  \
# count                                          56.000000
# mean                                        50365.767857
# std                                         24572.474288
# min                                         18472.000000
# 25%                                         31903.750000
# 50%                                         42863.500000
# 75%                                         57604.500000
# max                                        138289.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_25_to_44_years_-_Margin_of_Error  \
# count                                          56.000000
# mean                                        17955.071429
# std                                         10390.733469
# min                                          1086.000000
# 25%                                         11577.500000
# 50%                                         15923.000000
# 75%                                         23496.000000
# max                                         60445.000000
#
#        ...  Total_Households  Total_Households_-_Margin_of_Error  \
# count  ...         56.000000                           56.000000
# mean   ...       1716.732143                          143.767857
# std    ...        938.993281                           61.381961
# min    ...         20.000000                           10.000000
# 25%    ...        940.250000                           97.500000
# 50%    ...       1581.500000                          138.000000
# 75%    ...       2373.250000                          184.500000
# max    ...       4179.000000                          290.000000
#
#        Households_with_any_self-employment_income_in_past_12_months  \
# count                                          56.000000
# mean                                          137.250000
# std                                           112.659947
# min                                             0.000000
# 25%                                            62.250000
# 50%                                           108.500000
# 75%                                           165.250000
# max                                           508.000000
#
#        Households_with_any_self-employment_income_in_past_12_months_-_Margin_of_Error  \
# count                                          56.000000
# mean                                           67.571429
# std                                            37.913230
# min                                             8.000000
# 25%                                            43.750000
# 50%                                            64.000000
# 75%                                            83.250000
# max                                           182.000000
#
#        Households_with_no_self-employment_income_in_past_12_months  \
# count                                          56.000000
# mean                                         1579.482143
# std                                           853.825402
# min                                            20.000000
# 25%                                           868.750000
# 50%                                          1491.000000
# 75%                                          2226.750000
# max                                          3733.000000
#
#        Households_with_no_self-employment_income_in_past_12_months_-_Margin_of_Error  \
# count                                          56.000000
# mean                                          151.303571
# std                                            65.144014
# min                                            10.000000
# 25%                                           102.000000
# 50%                                           150.500000
# 75%                                           203.250000
# max                                           295.000000
#
#        Percent_of_households_with_any_self-employment_income  \
# count                                          56.000000
# mean                                            7.723214
# std                                             4.090432
# min                                             0.000000
# 25%                                             4.925000
# 50%                                             7.550000
# 75%                                            10.150000
# max                                            17.500000
#
#        Percent_of_households_with_any_self-employment_income_-_Margin_of_Error  \
# count                                          56.000000
# mean                                            5.730302
# std                                            12.238767
# min                                             1.057991
# 25%                                             3.048839
# 50%                                             4.011236
# 75%                                             5.240766
# max                                            95.000000
#
#          Shape_Area   Shape_Length
# count  5.600000e+01      56.000000
# mean   5.955961e+07   27750.509212
# std    1.109085e+08   30066.950130
# min    6.965757e+05    3425.491891
# 25%    3.343659e+06    8256.075886
# 50%    1.018591e+07   14826.730815
# 75%    3.570338e+07   33859.715993
# max    5.380157e+08  137229.394200
#
# [8 rows x 40 columns]
#
# Descriptive Statistics for 2023:
#           Object_ID  Geographic_Identifier_-_FIPS_Code  \
# count     58.000000                       5.800000e+01
# mean   19681.810345                       1.200100e+10
# std    31512.041131                       1.436027e+04
# min     2865.000000                       1.200100e+10
# 25%     2879.250000                       1.200100e+10
# 50%     2901.500000                       1.200100e+10
# 75%     2917.750000                       1.200100e+10
# max    77809.000000                       1.200111e+10
#
#        Area_of_Land_(Square_Meters)  Area_of_Water_(Square_Meters)  \
# count                  5.800000e+01                   5.800000e+01
# mean                   3.910191e+07                   4.160205e+06
# std                    5.931211e+07                   1.396987e+07
# min                    5.246390e+05                   0.000000e+00
# 25%                    2.678517e+06                   8.745500e+03
# 50%                    7.858146e+06                   5.098550e+04
# 75%                    5.529464e+07                   9.131710e+05
# max                    2.703086e+08                   8.233594e+07
#
#        Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)  \
# count                                          58.000000
# mean                                        59904.586207
# std                                         31038.824051
# min                                          2499.000000
# 25%                                         39019.250000
# 50%                                         53953.500000
# 75%                                         78012.750000
# max                                        154662.000000
#
#        Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_-_Margin_of_Error  \
# count                                          58.000000
# mean                                        12444.155172
# std                                          6868.984245
# min                                             0.000000
# 25%                                          7154.250000
# 50%                                         11543.000000
# 75%                                         16788.000000
# max                                         30453.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_under_25_years  \
# count                                          58.000000
# mean                                        10318.482759
# std                                         18914.913260
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                         14776.250000
# max                                         71026.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_under_25_years_-_Margin_of_Error  \
# count                                          58.000000
# mean                                         5098.068966
# std                                         11913.193173
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                          4565.250000
# max                                         59380.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_25_to_44_years  \
# count                                          58.000000
# mean                                        68620.275862
# std                                         43905.484813
# min                                             0.000000
# 25%                                         41697.000000
# 50%                                         60507.500000
# 75%                                         93672.000000
# max                                        211719.000000
#
#        Median_Household_Income_in_past_12_months,_Householder_25_to_44_years_-_Margin_of_Error  \
# count                                          58.000000
# mean                                        21287.931034
# std                                         15296.869581
# min                                             0.000000
# 25%                                         10877.000000
# 50%                                         20515.000000
# 75%                                         28663.000000
# max                                         68041.000000
#
#        ...  Total_Households  Total_Households_-_Margin_of_Error  \
# count  ...         58.000000                           58.000000
# mean   ...       1872.362069                          256.689655
# std    ...        938.172032                          107.195216
# min    ...         66.000000                           35.000000
# 25%    ...       1192.750000                          164.750000
# 50%    ...       1823.500000                          245.500000
# 75%    ...       2441.750000                          330.000000
# max    ...       4521.000000                          479.000000
#
#        Households_with_any_self-employment_income_in_past_12_months  \
# count                                          58.000000
# mean                                          171.448276
# std                                           110.265894
# min                                             0.000000
# 25%                                            94.000000
# 50%                                           158.000000
# 75%                                           231.500000
# max                                           511.000000
#
#        Households_with_any_self-employment_income_in_past_12_months_-_Margin_of_Error  \
# count                                          58.000000
# mean                                          100.431034
# std                                            58.901974
# min                                            16.000000
# 25%                                            56.250000
# 50%                                            98.500000
# 75%                                           128.750000
# max                                           370.000000
#
#        Households_with_no_self-employment_income_in_past_12_months  \
# count                                          58.000000
# mean                                         1700.913793
# std                                           875.007996
# min                                            66.000000
# 25%                                          1089.000000
# 50%                                          1646.000000
# 75%                                          2277.500000
# max                                          4247.000000
#
#        Households_with_no_self-employment_income_in_past_12_months_-_Margin_of_Error  \
# count                                          58.000000
# mean                                          256.655172
# std                                           104.419792
# min                                            35.000000
# 25%                                           167.000000
# 50%                                           245.000000
# 75%                                           328.000000
# max                                           484.000000
#
#        Percent_of_households_with_any_self-employment_income  \
# count                                          58.000000
# mean                                            9.094828
# std                                             4.528523
# min                                             0.000000
# 25%                                             5.725000
# 50%                                             8.350000
# 75%                                            12.150000
# max                                            22.800000
#
#        Percent_of_households_with_any_self-employment_income_-_Margin_of_Error  \
# count                                          58.000000
# mean                                            5.855174
# std                                             4.243421
# min                                             2.293135
# 25%                                             3.833434
# 50%                                             4.848863
# 75%                                             6.716746
# max                                            31.818182
#
#          Shape_Area   Shape_Length
# count  5.800000e+01      58.000000
# mean   5.533651e+07   32606.976678
# std    8.472674e+07   42033.417977
# min    6.965721e+05    3425.491947
# 25%    3.738037e+06    9029.782616
# 50%    1.047928e+07   14869.781180
# 75%    7.412839e+07   43618.463243
# max    3.686790e+08  214857.982200
#
# [8 rows x 40 columns]

# %%
t_test_results = {
    'Past_12_months_income': ttest_rel(ACS_merge['Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2023'], ACS_merge['Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2014']),
    'Past_12_months_income_under_25y': ttest_rel(ACS_merge['Median_Household_Income_in_past_12_months,_Householder_under_25_years_2023'], ACS_merge['Median_Household_Income_in_past_12_months,_Householder_under_25_years_2014']),
    'Past_12_months_income_African_American': ttest_rel(ACS_merge['Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2023'], ACS_merge['Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2014']),
    'Total_House_Hold': ttest_rel(ACS_merge['Total_Households_2023'], ACS_merge['Total_Households_2014'])
}

print("\nPaired t-test Results:")
for key, value in t_test_results.items():
    print(f"{key}: t-statistic ={value.statistic}, p-value = {value.pvalue}")
# Out:
# Paired t-test Results:
# Past_12_months_income: t-statistic =6.883280749740637, p-value = 1.6954078693061776e-08
# Past_12_months_income_under_25y: t-statistic =0.28770938062676665, p-value = 0.7749200262946419
# Past_12_months_income_African_American: t-statistic =0.9122331886276916, p-value = 0.36661726652288684
# Total_House_Hold: t-statistic =6.735233075837132, p-value = 2.7969565884388045e-08

# %%
wilcoxon_results = {
    'Past_12_months_income': wilcoxon(ACS_merge['Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2023'], ACS_merge['Median_Household_Income_in_past_12_months_(inflation-adjusted_dollars_to_last_year_of_5-year_range)_2014']),
    'Past_12_months_income_under_25y': wilcoxon(ACS_merge['Median_Household_Income_in_past_12_months,_Householder_under_25_years_2023'], ACS_merge['Median_Household_Income_in_past_12_months,_Householder_under_25_years_2014']),
    'Past_12_months_income_African_American': wilcoxon(ACS_merge['Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2023'], ACS_merge['Median_Household_Income_in_past_12_months,_Black_or_African_American_Alone_Householder_2014']),
    'Total_House_Hold': wilcoxon(ACS_merge['Total_Households_2023'], ACS_merge['Total_Households_2014'])
}

print("\nWilcoxon signed-rank test Results:")
for key, value in wilcoxon_results.items():
    print(f"{key}: statistic = {result.statistic}, p-value = {value.pvalue}")
# Out:
# Wilcoxon signed-rank test Results:
# Past_12_months_income: statistic = 77.0, p-value = 5.0145445129601285e-08
# Past_12_months_income_under_25y: statistic = 77.0, p-value = 0.9531185402094994
# Past_12_months_income_African_American: statistic = 77.0, p-value = 0.14869027289034498
# Total_House_Hold: statistic = 77.0, p-value = 3.407143367439858e-08
# C:\Users\jai04\anaconda3\New folder\Lib\site-packages\scipy\stats\_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
